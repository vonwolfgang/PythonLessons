# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib as plt

# %%
variable = pd.read_csv(r"C:\Users\Computer\Desktop\seaborn\train.csv")

# %%
variable
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
## yukarıdaki gibi import lar ile ve read_csv komutu ile export edebilirsin

# %%
variable.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
variable.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
## .dtypes ile veri tiplerini görebilirsin

# %%
variable.size
# Out:
# 10692

# %%
## .size ile toplam veri sayısını öğrendik

# %%
variable.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
variable.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
variable = variable.dropna()

# %%
variable.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
a = sns.barplot(x = "Sex" , y = "Survived" , hue = "Sex" , data = variable);
a.set_title("survived number ");

# %%
## yukarıda yaptığımız şey sns.barplot() ile bi görsel oluşturduk burda x ' e sex verdik y ' e ise survived verdik 
## hue dediğimiz şey yeni bi boyut ekleyerek sex kırılımına bakması gerektiğini söyledik data  olarak variable kullan dedik 
## ; ise bize ayrıntıyı değil sadece görseli göster demek

# %%
sns.pairplot(variable);

# %%
## güzel bi grafik yaptı

# %%
corr = variable.corr()

# %%
a = sns.heatmap(corr,vmax=.99,linewidth = 0.5 , square = True , annot = True , linecolor = "black")

# %%
## yukarıda güzel bi grafik daha yaptık

# %%
countplot = sns.countplot(x=variable.Sex)

# %%
## buna countplot grafiği denir bu sayede bişeler yaptık

# %%
sns.catplot(x="Pclass",kind="count",hue="Sex",palette="Set1",data=variable)

# %%
## buda countplot grafiğiydi

# %%
sns.catplot(x = "Sex" , y = "Fare" ,kind = "box" , hue = "Sex" , sym = "" , data = variable)

# %%
## outlier değerlerine bakarak yorum yapmamızı sağlar

# %%
sns.scatterplot(x = "Fare" , y = "Age" , data = variable , hue = "Sex"  );

# %%
## böle garip grafikler yapabilioz
